# %% [markdown]
# # Loading Data

# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import math
import statistics as stats
import matplotlib.pyplot as plt

a = np.loadtxt('po1_data.txt',  delimiter = ',')


print(a)

df = pd.DataFrame(a)


df.columns = ['subject identifier', ' jitter in %', 'absolute jitter in ms', 'jitter r.a.p.', 'jitter p.p.q.5','jitter d.d.p.' ,
              'shimmer in %','absolute shimmer dB', 'shimmer a.p.q.3', 'shimmer a.p.q.5','shimmer a.p.q.11','shimmer d.d.a', 
              'autocorrelation between NHR and HNR', 'NHR','HNR','median pitch','mean pitch','sd of pitch','min pitch',
              'max pitch','number of pulses','number of periods','mean period','sd of period','fraction of unvoiced frames',
              'num of voice breaks','degree of voice breaks','UPDRS','PD label']


print(df)

column_names = list(df.columns)
# Out:
# [[1.00000e+00 1.48800e+00 9.02130e-05 ... 0.00000e+00 2.30000e+01
#   1.00000e+00]
#  [1.00000e+00 7.28000e-01 3.76980e-05 ... 0.00000e+00 2.30000e+01
#   1.00000e+00]
#  [1.00000e+00 1.22000e+00 7.40410e-05 ... 1.78000e-01 2.30000e+01
#   1.00000e+00]
#  ...
#  [4.00000e+01 2.91200e+00 2.26205e-04 ... 4.57400e+00 1.00000e+00
#   0.00000e+00]
#  [4.00000e+01 3.78800e+00 2.74883e-04 ... 1.95750e+01 1.00000e+00
#   0.00000e+00]
#  [4.00000e+01 1.80900e+00 1.48510e-04 ... 3.38700e+00 1.00000e+00
#   0.00000e+00]]
#       subject identifier   jitter in %  absolute jitter in ms  jitter r.a.p.  \
# 0                    1.0         1.488               0.000090          0.900
# 1                    1.0         0.728               0.000038          0.353
# 2                    1.0         1.220               0.000074          0.732
# 3                    1.0         2.502               0.000123          1.156
# 4                    1.0         3.509               0.000167          1.715
# ...                  ...           ...                    ...            ...
# 1035                40.0         5.127               0.000398          2.721
# 1036                40.0         1.757               0.000133          0.808
# 1037                40.0         2.912               0.000226          1.141
# 1038                40.0         3.788               0.000275          1.786
# 1039                40.0         1.809               0.000149          0.680
#
#       jitter p.p.q.5  jitter d.d.p.  shimmer in %  absolute shimmer dB  \
# 0              0.794          2.699         8.334                0.779
# 1              0.376          1.059         5.864                0.642
# 2              0.670          2.196         8.719                0.875
# 3              1.634          3.469        13.513                1.273
# 4              1.539          5.145         9.112                1.040
# ...              ...            ...           ...                  ...
# 1035           2.510          8.162         9.846                0.965
# 1036           0.690          2.425         7.571                0.740
# 1037           1.266          3.423        15.489                1.456
# 1038           1.484          5.359        15.702                1.367
# 1039           0.843          2.040         7.881                0.782
#
#       shimmer a.p.q.3  shimmer a.p.q.5  ...  max pitch  number of pulses  \
# 0               4.517            4.609  ...    187.576             160.0
# 1               2.058            3.180  ...    234.505             170.0
# 2               4.347            5.166  ...    211.442            1431.0
# 3               5.263            8.771  ...    220.230              94.0
# 4               3.102            4.927  ...    225.162             117.0
# ...               ...              ...  ...        ...               ...
# 1035            4.593            6.806  ...    158.591              63.0
# 1036            2.720            3.927  ...    143.797              47.0
# 1037            6.433           10.138  ...    149.641              79.0
# 1038            6.374           11.094  ...    451.366              75.0
# 1039            2.690            4.543  ...    137.546              62.0
#
#       number of periods  mean period  sd of period  \
# 0                 159.0     0.006065      0.000416
# 1                 169.0     0.005181      0.000403
# 2                1427.0     0.006071      0.000474
# 3                  92.0     0.004910      0.000320
# 4                 114.0     0.004757      0.000380
# ...                 ...          ...           ...
# 1035               60.0     0.007766      0.001066
# 1036               44.0     0.007561      0.000430
# 1037               77.0     0.007767      0.000881
# 1038               70.0     0.007257      0.001714
# 1039               60.0     0.008211      0.000566
#
#       fraction of unvoiced frames  num of voice breaks  \
# 0                           0.000                  0.0
# 1                           2.247                  0.0
# 2                          10.656                  1.0
# 3                           0.000                  0.0
# 4                          18.182                  1.0
# ...                           ...                  ...
# 1035                       24.194                  2.0
# 1036                       46.053                  1.0
# 1037                       20.000                  1.0
# 1038                       16.667                  3.0
# 1039                       18.182                  1.0
#
#       degree of voice breaks  UPDRS  PD label
# 0                      0.000   23.0       1.0
# 1                      0.000   23.0       1.0
# 2                      0.178   23.0       1.0
# 3                      0.000   23.0       1.0
# 4                     13.318   23.0       1.0
# ...                      ...    ...       ...
# 1035                  15.113    1.0       0.0
# 1036                  25.792    1.0       0.0
# 1037                   4.574    1.0       0.0
# 1038                  19.575    1.0       0.0
# 1039                   3.387    1.0       0.0
#
# [1040 rows x 29 columns]

# %% [markdown]
# # Data Wrangling

# %%
df.isnull()

print(df.describe())

print(df.dtypes)

print(df.info())
# Out:
#        subject identifier   jitter in %  absolute jitter in ms  jitter r.a.p.  \
# count          1040.00000   1040.000000            1040.000000    1040.000000
# mean             20.50000      2.679523               0.000170       1.247053
# std              11.54895      1.765053               0.000106       0.979462
# min               1.00000      0.190000               0.000006       0.062000
# 25%              10.75000      1.507500               0.000095       0.617000
# 50%              20.50000      2.396000               0.000151       1.035500
# 75%              30.25000      3.411500               0.000229       1.602500
# max              40.00000     14.376000               0.000777       8.016000
#
#        jitter p.p.q.5  jitter d.d.p.  shimmer in %  absolute shimmer dB  \
# count     1040.000000    1040.000000   1040.000000          1040.000000
# mean         1.348327       3.741161     12.918391             1.194895
# std          1.138742       2.938443      5.452204             0.420071
# min          0.081000       0.185000      1.185000             0.103000
# 25%          0.665750       1.851750      9.353500             0.941000
# 50%          1.126500       3.107000     12.348500             1.181500
# 75%          1.694750       4.808500     15.493250             1.411000
# max         13.542000      24.048000     41.137000             2.721000
#
#        shimmer a.p.q.3  shimmer a.p.q.5  ...    max pitch  number of pulses  \
# count      1040.000000      1040.000000  ...  1040.000000       1040.000000
# mean          5.699600         7.983552  ...   234.875990        109.744231
# std           3.015183         4.840892  ...   121.541243        150.027703
# min           0.496000         0.708000  ...    85.541000          0.000000
# 25%           3.703000         5.160250  ...   143.650750         42.750000
# 50%           5.134500         7.050500  ...   195.971000         65.000000
# 75%           6.942000         9.558930  ...   263.798250        113.000000
# max          25.820000        72.860000  ...   597.974000       1490.000000
#
#        number of periods  mean period  sd of period  \
# count        1040.000000  1040.000000   1040.000000
# mean          105.969231     0.006547      0.000843
# std           149.417074     0.001875      0.000723
# min             0.000000     0.002039      0.000055
# 25%            40.750000     0.005039      0.000404
# 50%            62.000000     0.006484      0.000644
# 75%           109.000000     0.007923      0.000980
# max          1489.000000     0.012070      0.006371
#
#        fraction of unvoiced frames  num of voice breaks  \
# count                  1040.000000          1040.000000
# mean                     27.682856             1.134615
# std                      20.975294             1.614764
# min                       0.000000             0.000000
# 25%                       8.149250             0.000000
# 50%                      26.501000             1.000000
# 75%                      43.064250             1.000000
# max                      88.158000            12.000000
#
#        degree of voice breaks        UPDRS     PD label
# count             1040.000000  1040.000000  1040.000000
# mean                12.370042    13.000000     0.500000
# std                 15.161916    15.894745     0.500241
# min                  0.000000     1.000000     0.000000
# 25%                  0.000000     1.000000     0.000000
# 50%                  5.826000     3.000000     0.500000
# 75%                 22.255500    23.250000     1.000000
# max                 69.117000    55.000000     1.000000
#
# [8 rows x 29 columns]
# subject identifier                     float64
#  jitter in %                           float64
# absolute jitter in ms                  float64
# jitter r.a.p.                          float64
# jitter p.p.q.5                         float64
# jitter d.d.p.                          float64
# shimmer in %                           float64
# absolute shimmer dB                    float64
# shimmer a.p.q.3                        float64
# shimmer a.p.q.5                        float64
# shimmer a.p.q.11                       float64
# shimmer d.d.a                          float64
# autocorrelation between NHR and HNR    float64
# NHR                                    float64
# HNR                                    float64
# median pitch                           float64
# mean pitch                             float64
# sd of pitch                            float64
# min pitch                              float64
# max pitch                              float64
# number of pulses                       float64
# number of periods                      float64
# mean period                            float64
# sd of period                           float64
# fraction of unvoiced frames            float64
# num of voice breaks                    float64
# degree of voice breaks                 float64
# UPDRS                                  float64
# PD label                               float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1040 entries, 0 to 1039
# Data columns (total 29 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   subject identifier                   1040 non-null   float64
#  1    jitter in %                         1040 non-null   float64
#  2   absolute jitter in ms                1040 non-null   float64
#  3   jitter r.a.p.                        1040 non-null   float64
#  4   jitter p.p.q.5                       1040 non-null   float64
#  5   jitter d.d.p.                        1040 non-null   float64
#  6   shimmer in %                         1040 non-null   float64
#  7   absolute shimmer dB                  1040 non-null   float64
#  8   shimmer a.p.q.3                      1040 non-null   float64
#  9   shimmer a.p.q.5                      1040 non-null   float64
#  10  shimmer a.p.q.11                     1040 non-null   float64
#  11  shimmer d.d.a                        1040 non-null   float64
#  12  autocorrelation between NHR and HNR  1040 non-null   float64
#  13  NHR                                  1040 non-null   float64
#  14  HNR                                  1040 non-null   float64
#  15  median pitch                         1040 non-null   float64
#  16  mean pitch                           1040 non-null   float64
#  17  sd of pitch                          1040 non-null   float64
#  18  min pitch                            1040 non-null   float64
#  19  max pitch                            1040 non-null   float64
#  20  number of pulses                     1040 non-null   float64
#  21  number of periods                    1040 non-null   float64
#  22  mean period                          1040 non-null   float64
#  23  sd of period                         1040 non-null   float64
#  24  fraction of unvoiced frames          1040 non-null   float64
#  25  num of voice breaks                  1040 non-null   float64
#  26  degree of voice breaks               1040 non-null   float64
#  27  UPDRS                                1040 non-null   float64
#  28  PD label                             1040 non-null   float64
# dtypes: float64(29)
# memory usage: 235.8 KB
# None

# %%
df1 = df[df["PD label"] == 1]
df2 = df[df["PD label"] == 0]

# %% [markdown]
# # t-test

# %%
salient_features = []
for i in range(1,28):
    print('Analysis of the measurement variable', column_names[i])
    print()
    sample1 = df1.iloc[:, i].to_numpy()
    sample2 = df2.iloc[:, i].to_numpy()
    
    

    # the basic statistics of sample 1:
    x_bar1 = st.tmean(sample1)
    s1 = st.tstd(sample1)
    n1 = len(sample1)
    print("\n Statistics of sample 1: %.3f (mean), %.3f (std. dev.), and %d (n)." % (x_bar1, s1, n1))
    plt.hist(sample1, color='Red', edgecolor='black')
    plt.title("Histogram View")
    plt.xlabel(column_names[i])
    plt.ylabel("Frequency")
    plt.show()
    
    
    # the basic statistics of sample 2:
    x_bar2 = st.tmean(sample2)
    s2 = st.tstd(sample2)
    n2 = len(sample2)
    print("\n Statistics of sample 2: %.3f (mean), %.3f (std. dev.), and %d (n)." % (x_bar2, s2, n2))
    plt.hist(sample2, color='Yellow', edgecolor='black')
    plt.title("Histogram View")
    plt.xlabel(column_names[i])
    plt.ylabel("Frequency")
    plt.show()

    # perform two-sample t-test
    # null hypothesis: mean of sample 1 = mean of sample 2
    # alternative hypothesis: mean of sample 1 is not equal to mean of sample 2
    # note the argument equal_var=False, which assumes that two populations do not have equal variance
    t_stats, p_val = st.ttest_ind_from_stats(x_bar1, s1, n1, x_bar2, s2, n2, equal_var=False, alternative='two-sided')
    print("\n Computing t* ...")
    print("\t t-statistic (t*): %.2f" % t_stats)

    print("\n Computing p-value ...")
    print("\t p-value: %.4f" % p_val)

    print("\n Conclusion:")
    if p_val < 0.05:
        print("\t We reject the null hypothesis for", column_names[i])
        salient_features.append(column_names[i])
    else:
        print("\t We accept the null hypothesis for", column_names[i])
        print()
# Out:
# Analysis of the measurement variable  jitter in %
#
#
#  Statistics of sample 1: 2.852 (mean), 1.681 (std. dev.), and 520 (n).
#  Statistics of sample 2: 2.507 (mean), 1.831 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): 3.16
#
#  Computing p-value ...
# 	 p-value: 0.0016
#
#  Conclusion:
# 	 We reject the null hypothesis for  jitter in %
# Analysis of the measurement variable absolute jitter in ms
#
#
#  Statistics of sample 1: 0.000 (mean), 0.000 (std. dev.), and 520 (n).
#  Statistics of sample 2: 0.000 (mean), 0.000 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): 5.46
#
#  Computing p-value ...
# 	 p-value: 0.0000
#
#  Conclusion:
# 	 We reject the null hypothesis for absolute jitter in ms
# Analysis of the measurement variable jitter r.a.p.
#
#
#  Statistics of sample 1: 1.356 (mean), 0.918 (std. dev.), and 520 (n).
#  Statistics of sample 2: 1.138 (mean), 1.027 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): 3.60
#
#  Computing p-value ...
# 	 p-value: 0.0003
#
#  Conclusion:
# 	 We reject the null hypothesis for jitter r.a.p.
# Analysis of the measurement variable jitter p.p.q.5
#
#
#  Statistics of sample 1: 1.475 (mean), 1.019 (std. dev.), and 520 (n).
#  Statistics of sample 2: 1.222 (mean), 1.235 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): 3.60
#
#  Computing p-value ...
# 	 p-value: 0.0003
#
#  Conclusion:
# 	 We reject the null hypothesis for jitter p.p.q.5
# Analysis of the measurement variable jitter d.d.p.
#
#
#  Statistics of sample 1: 4.068 (mean), 2.753 (std. dev.), and 520 (n).
#  Statistics of sample 2: 3.415 (mean), 3.081 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): 3.60
#
#  Computing p-value ...
# 	 p-value: 0.0003
#
#  Conclusion:
# 	 We reject the null hypothesis for jitter d.d.p.
# Analysis of the measurement variable shimmer in %
#
#
#  Statistics of sample 1: 12.968 (mean), 4.710 (std. dev.), and 520 (n).
#  Statistics of sample 2: 12.869 (mean), 6.109 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): 0.29
#
#  Computing p-value ...
# 	 p-value: 0.7704
#
#  Conclusion:
# 	 We accept the null hypothesis for shimmer in %
#
# Analysis of the measurement variable absolute shimmer dB
#
#
#  Statistics of sample 1: 1.206 (mean), 0.366 (std. dev.), and 520 (n).
#  Statistics of sample 2: 1.183 (mean), 0.468 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): 0.88
#
#  Computing p-value ...
# 	 p-value: 0.3811
#
#  Conclusion:
# 	 We accept the null hypothesis for absolute shimmer dB
#
# Analysis of the measurement variable shimmer a.p.q.3
#
#
#  Statistics of sample 1: 5.645 (mean), 2.485 (std. dev.), and 520 (n).
#  Statistics of sample 2: 5.754 (mean), 3.467 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): -0.59
#
#  Computing p-value ...
# 	 p-value: 0.5586
#
#  Conclusion:
# 	 We accept the null hypothesis for shimmer a.p.q.3
#
# Analysis of the measurement variable shimmer a.p.q.5
#
#
#  Statistics of sample 1: 7.874 (mean), 3.514 (std. dev.), and 520 (n).
#  Statistics of sample 2: 8.093 (mean), 5.877 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): -0.73
#
#  Computing p-value ...
# 	 p-value: 0.4670
#
#  Conclusion:
# 	 We accept the null hypothesis for shimmer a.p.q.5
#
# Analysis of the measurement variable shimmer a.p.q.11
#
#
#  Statistics of sample 1: 13.095 (mean), 6.328 (std. dev.), and 520 (n).
#  Statistics of sample 2: 11.335 (mean), 5.555 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): 4.77
#
#  Computing p-value ...
# 	 p-value: 0.0000
#
#  Conclusion:
# 	 We reject the null hypothesis for shimmer a.p.q.11
# Analysis of the measurement variable shimmer d.d.a
#
#
#  Statistics of sample 1: 16.935 (mean), 7.454 (std. dev.), and 520 (n).
#  Statistics of sample 2: 17.263 (mean), 10.401 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): -0.59
#
#  Computing p-value ...
# 	 p-value: 0.5586
#
#  Conclusion:
# 	 We accept the null hypothesis for shimmer d.d.a
#
# Analysis of the measurement variable autocorrelation between NHR and HNR
#
#
#  Statistics of sample 1: 0.853 (mean), 0.074 (std. dev.), and 520 (n).
#  Statistics of sample 2: 0.839 (mean), 0.096 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): 2.62
#
#  Computing p-value ...
# 	 p-value: 0.0089
#
#  Conclusion:
# 	 We reject the null hypothesis for autocorrelation between NHR and HNR
# Analysis of the measurement variable NHR
#
#
#  Statistics of sample 1: 0.220 (mean), 0.131 (std. dev.), and 520 (n).
#  Statistics of sample 2: 0.243 (mean), 0.169 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): -2.46
#
#  Computing p-value ...
# 	 p-value: 0.0141
#
#  Conclusion:
# 	 We reject the null hypothesis for NHR
# Analysis of the measurement variable HNR
#
#
#  Statistics of sample 1: 10.173 (mean), 3.894 (std. dev.), and 520 (n).
#  Statistics of sample 2: 9.826 (mean), 4.652 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): 1.31
#
#  Computing p-value ...
# 	 p-value: 0.1918
#
#  Conclusion:
# 	 We accept the null hypothesis for HNR
#
# Analysis of the measurement variable median pitch
#
#
#  Statistics of sample 1: 158.652 (mean), 46.842 (std. dev.), and 520 (n).
#  Statistics of sample 2: 168.084 (mean), 63.593 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): -2.72
#
#  Computing p-value ...
# 	 p-value: 0.0066
#
#  Conclusion:
# 	 We reject the null hypothesis for median pitch
# Analysis of the measurement variable mean pitch
#
#
#  Statistics of sample 1: 162.950 (mean), 48.761 (std. dev.), and 520 (n).
#  Statistics of sample 2: 174.505 (mean), 61.861 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): -3.35
#
#  Computing p-value ...
# 	 p-value: 0.0009
#
#  Conclusion:
# 	 We reject the null hypothesis for mean pitch
# Analysis of the measurement variable sd of pitch
#
#
#  Statistics of sample 1: 23.110 (mean), 34.324 (std. dev.), and 520 (n).
#  Statistics of sample 2: 31.986 (mean), 38.403 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): -3.93
#
#  Computing p-value ...
# 	 p-value: 0.0001
#
#  Conclusion:
# 	 We reject the null hypothesis for sd of pitch
# Analysis of the measurement variable min pitch
#
#
#  Statistics of sample 1: 131.758 (mean), 42.893 (std. dev.), and 520 (n).
#  Statistics of sample 2: 137.318 (mean), 50.773 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): -1.91
#
#  Computing p-value ...
# 	 p-value: 0.0567
#
#  Conclusion:
# 	 We accept the null hypothesis for min pitch
#
# Analysis of the measurement variable max pitch
#
#
#  Statistics of sample 1: 217.941 (mean), 109.385 (std. dev.), and 520 (n).
#  Statistics of sample 2: 251.810 (mean), 130.512 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): -4.54
#
#  Computing p-value ...
# 	 p-value: 0.0000
#
#  Conclusion:
# 	 We reject the null hypothesis for max pitch
# Analysis of the measurement variable number of pulses
#
#
#  Statistics of sample 1: 115.898 (mean), 178.532 (std. dev.), and 520 (n).
#  Statistics of sample 2: 103.590 (mean), 114.500 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): 1.32
#
#  Computing p-value ...
# 	 p-value: 0.1861
#
#  Conclusion:
# 	 We accept the null hypothesis for number of pulses
#
# Analysis of the measurement variable number of periods
#
#
#  Statistics of sample 1: 113.004 (mean), 178.372 (std. dev.), and 520 (n).
#  Statistics of sample 2: 98.935 (mean), 113.041 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): 1.52
#
#  Computing p-value ...
# 	 p-value: 0.1291
#
#  Conclusion:
# 	 We accept the null hypothesis for number of periods
#
# Analysis of the measurement variable mean period
#
#
#  Statistics of sample 1: 0.007 (mean), 0.002 (std. dev.), and 520 (n).
#  Statistics of sample 2: 0.006 (mean), 0.002 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): 2.64
#
#  Computing p-value ...
# 	 p-value: 0.0083
#
#  Conclusion:
# 	 We reject the null hypothesis for mean period
# Analysis of the measurement variable sd of period
#
#
#  Statistics of sample 1: 0.001 (mean), 0.001 (std. dev.), and 520 (n).
#  Statistics of sample 2: 0.001 (mean), 0.001 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): -1.90
#
#  Computing p-value ...
# 	 p-value: 0.0581
#
#  Conclusion:
# 	 We accept the null hypothesis for sd of period
#
# Analysis of the measurement variable fraction of unvoiced frames
#
#
#  Statistics of sample 1: 25.124 (mean), 20.661 (std. dev.), and 520 (n).
#  Statistics of sample 2: 30.242 (mean), 20.994 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): -3.96
#
#  Computing p-value ...
# 	 p-value: 0.0001
#
#  Conclusion:
# 	 We reject the null hypothesis for fraction of unvoiced frames
# Analysis of the measurement variable num of voice breaks
#
#
#  Statistics of sample 1: 1.006 (mean), 1.470 (std. dev.), and 520 (n).
#  Statistics of sample 2: 1.263 (mean), 1.740 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): -2.58
#
#  Computing p-value ...
# 	 p-value: 0.0100
#
#  Conclusion:
# 	 We reject the null hypothesis for num of voice breaks
# Analysis of the measurement variable degree of voice breaks
#
#
#  Statistics of sample 1: 10.458 (mean), 13.763 (std. dev.), and 520 (n).
#  Statistics of sample 2: 14.282 (mean), 16.232 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): -4.10
#
#  Computing p-value ...
# 	 p-value: 0.0000
#
#  Conclusion:
# 	 We reject the null hypothesis for degree of voice breaks
# Analysis of the measurement variable UPDRS
#
#
#  Statistics of sample 1: 25.000 (mean), 14.738 (std. dev.), and 520 (n).
#  Statistics of sample 2: 1.000 (mean), 0.000 (std. dev.), and 520 (n).
#  Computing t* ...
# 	 t-statistic (t*): 37.13
#
#  Computing p-value ...
# 	 p-value: 0.0000
#
#  Conclusion:
# 	 We reject the null hypothesis for UPDRS

# %% [markdown]
# # Output

# %%
print(salient_features)
# Out:
# [' jitter in %', 'absolute jitter in ms', 'jitter r.a.p.', 'jitter p.p.q.5', 'jitter d.d.p.', 'shimmer a.p.q.11', 'autocorrelation between NHR and HNR', 'NHR', 'median pitch', 'mean pitch', 'sd of pitch', 'max pitch', 'mean period', 'fraction of unvoiced frames', 'num of voice breaks', 'degree of voice breaks', 'UPDRS']

# %%
len(salient_features)
# Out:
# 17
